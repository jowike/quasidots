# %%
# %cd ..
# !pip install -e .
# Out:
# /Users/elajowik/Documents/quasidots
# Obtaining file:///Users/elajowik/Documents/quasidots
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from quasidots==0.1) (2.3.5)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.13/site-packages (from quasidots==0.1) (1.7.2)
# Requirement already satisfied: numba in ./.venv/lib/python3.13/site-packages (from quasidots==0.1) (0.63.1)
# Requirement already satisfied: aeon in ./.venv/lib/python3.13/site-packages (from quasidots==0.1) (1.4.0)
# Requirement already satisfied: sktime in ./.venv/lib/python3.13/site-packages (from quasidots==0.1) (0.40.1)
# Requirement already satisfied: deprecated>=1.2.13 in ./.venv/lib/python3.13/site-packages (from aeon->quasidots==0.1) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from aeon->quasidots==0.1) (26.2)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in ./.venv/lib/python3.13/site-packages (from aeon->quasidots==0.1) (2.3.3)
# Requirement already satisfied: scipy<1.18.0,>=1.9.0 in ./.venv/lib/python3.13/site-packages (from aeon->quasidots==0.1) (1.17.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.13/site-packages (from aeon->quasidots==0.1) (4.15.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in ./.venv/lib/python3.13/site-packages (from numba->quasidots==0.1) (0.46.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas<2.4.0,>=2.0.0->aeon->quasidots==0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas<2.4.0,>=2.0.0->aeon->quasidots==0.1) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas<2.4.0,>=2.0.0->aeon->quasidots==0.1) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn->quasidots==0.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn->quasidots==0.1) (3.6.0)
# Requirement already satisfied: wrapt<3,>=1.10 in ./.venv/lib/python3.13/site-packages (from deprecated>=1.2.13->aeon->quasidots==0.1) (2.1.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->aeon->quasidots==0.1) (1.17.0)
# Requirement already satisfied: scikit-base<0.14.0,>=0.6.1 in ./.venv/lib/python3.13/site-packages (from sktime->quasidots==0.1) (0.13.2)
# Building wheels for collected packages: quasidots
#   Building editable for quasidots (pyproject.toml) ... done
#   Created wheel for quasidots: filename=quasidots-0.1-0.editable-py3-none-any.whl size=15027 sha256=4ffeafa0e367e38faf01d01a3c8a091a58037ddee676968997aac4e6c3537147
#   Stored in directory: /private/var/folders/3n/fc7xtc697j95r3x2077fvp1c0000gn/T/pip-ephem-wheel-cache-sul_f4r_/wheels/f2/56/3a/8abd7fd094a1db89d7fce9d0f4c82fe1e3354142419c9d674c
# Successfully built quasidots
# Installing collected packages: quasidots
#   Attempting uninstall: quasidots
#     Found existing installation: quasidots 0.1
#     Uninstalling quasidots-0.1:
#       Successfully uninstalled quasidots-0.1
# Successfully installed quasidots-0.1

# %%
from quasidots import QuasidoTSClassifier
from aeon.datasets import load_classification

# %%
dataset = "ECG200"

# %%
X_train, y_train = load_classification(dataset, split="train", load_equal_length=True, load_no_missing=True)
X_test, y_test = load_classification(dataset, split="test", load_equal_length=True, load_no_missing=True)
# Out:
# /var/folders/3n/fc7xtc697j95r3x2077fvp1c0000gn/T/ipykernel_13942/173600124.py:1: FutureWarning: Call to deprecated function (or staticmethod) load_classification. (load_classification parameters load_equal_length and load_no_missing will default to False in version 1.5.0) -- Deprecated since version 1.4.0.
#   X_train, y_train = load_classification(dataset, split="train", load_equal_length=True, load_no_missing=True)
# /var/folders/3n/fc7xtc697j95r3x2077fvp1c0000gn/T/ipykernel_13942/173600124.py:2: FutureWarning: Call to deprecated function (or staticmethod) load_classification. (load_classification parameters load_equal_length and load_no_missing will default to False in version 1.5.0) -- Deprecated since version 1.4.0.
#   X_test, y_test = load_classification(dataset, split="test", load_equal_length=True, load_no_missing=True)

# %%
clf = QuasidoTSClassifier(operation="AT", num_kernels=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
